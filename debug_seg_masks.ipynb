# %%
from micro_dl.input.gen_masks_seg import MaskCreator
mask_inst = MaskCreator(input_dir='/data/anitha/label_free_ff/split_images', input_channel_id=0,
                        output_dir='/data/anitha/label_free_ff/image_tile_256-256_step_64-64_vf-0.15',
                        output_channel_id=4)

# %%
mask_inst.create_masks_for_stack()

# %%
meta_info = mask_inst.tile_mask_stack(input_mask_dir=['/data/anitha/label_free_ff/split_images/timepoint_0/channel_4'],
                                     tile_index_fname='/data/anitha/label_free_ff/split_images/timepoint_0/mask_0-1_vf-0.15.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3e4d9a90241d> in <module>()
#       1 meta_info = mask_inst.tile_mask_stack(input_mask_dir=['/data/anitha/label_free_ff/split_images/timepoint_0/channel_4'],
# ----> 2                                      tile_index_fname='/data/anitha/label_free_ff/split_images/timepoint_0/mask_0-1_vf-0.15.pkl')
#
# ~/code/micro_dl/input/gen_masks_seg.py in tile_mask_stack(self, input_mask_dir, tile_index_fname, tile_size, step_size, isotropic)
#     158                         )
#     159             save_tile_meta(cropped_meta, cur_channel=cur_ch,
# --> 160                            tiled_dir=self.output_dir)
#
# ~/code/micro_dl/utils/aux_utils.py in save_tile_meta(cropped_meta, cur_channel, tiled_dir)
#     129                  'slice_num', fname_header]
#     130     )
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
mask = np.load('/data/anitha/label_free_ff/split_images/timepoint_0/channel_4/image_n249_z0.npy')
img = np.load('/data/anitha/label_free_ff/split_images/timepoint_0/channel_0/image_n249_z0.npy')
fig, ax = plt.subplots(1,3)
fig.set_size_inches(15, 5)
ax[0].imshow(mask, cmap='gray'); ax[0].axis('off')
ax[1].imshow(img, cmap='gray'); ax[1].axis('off')
mask_data = np.ma.masked_where(mask==0, mask)
ax[2].imshow(img, cmap='gray'); ax[2].imshow(mask_data, cmap='Blues', alpha=0.7); ax[2].axis('off')
# Out:
# (-0.5, 2047.5, 2047.5, -0.5)
